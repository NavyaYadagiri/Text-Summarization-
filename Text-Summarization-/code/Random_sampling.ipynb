# %%
#mount google drive to access the stored data set and manipulate it
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Setting up PySpark in Colab, designate where the installer should be located
# %cd /content/drive/MyDrive/CapstoneProject/medical_conversation_summarization-main/data/Original dataset
# Out:
# /content/drive/MyDrive/CapstoneProject/medical_conversation_summarization-main/data/Original dataset

# %%
import json

data = []
with open('dev.jsonl') as f:
    for line in f:
        data.append(json.loads(line))

# %%
import random
random.shuffle(data)

# %%
dev_data=data[:400]

# %%
with open('/content/drive/MyDrive/CapstoneProject/medical_conversation_summarization-main/data/dev.jsonl', 'w') as outfile:
    for entry in dev_data:
        json.dump(entry, outfile)
        outfile.write('\n')
